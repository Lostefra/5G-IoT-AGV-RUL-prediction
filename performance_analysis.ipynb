# %% [markdown]
# # Performance analysis

# %%
import pandas as pd

pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.2f' % x)

# %%
df_5 = pd.read_csv("testing_summary_5.csv", index_col=[0])
df_5
# Out:
#          model  seed       columns  \
# 0   raw_signal   100       Ax_diff
# 1  autoencoder   300   w5_features
# 2          mlp  2900   w5_features
# 3      conv_nn  1300  all_features
# 4         lstm   200  w15_features
# 5          gru   100  all_features
# 6       bilstm   300   w5_features
# 7  transformer   101  all_features
#
#                                                                                                                                              params  \
# 0                                                                                                                                                {}
# 1                                                                                                                  {'hidden_ae': [16, 8, 2, 8, 16]}
# 2                                                                                                                          {'hidden_mlp': [64, 32]}
# 3                                                                                  {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 4                                                                                                                  {'time_steps': 10, 'units': 128}
# 5                                                                                                                   {'time_steps': 5, 'units': 128}
# 6                                                                                                                   {'time_steps': 5, 'units': 128}
# 7  {'head_size': 128, 'num_heads': 2, 'ff_dim': 2, 'num_transformer_blocks': 2, 'mlp_units': [64], 'mlp_dropout': 0.3, 'dropout': 0.25, 'w_len': 5}
#
#    params_idx    cost  anticipation  detected_faults  missed_faults  \
# 0           0   80.80          0.24               12              1
# 1           0 2396.20          0.39               13              0
# 2           2   43.40          0.27               13              0
# 3          11   28.80          0.27               13              0
# 4           3   95.40          0.20               12              1
# 5           1   85.40          0.23               13              0
# 6           1   61.40          0.28               13              0
# 7           0   67.00          0.22               12              1
#
#    false_alarms
# 0           174
# 1         11976
# 2            82
# 3            29
# 4           157
# 5           217
# 6           177
# 7            45

# %%
df_10 = pd.read_csv("testing_summary_10.csv", index_col=[0])
df_10
# Out:
#          model  seed       columns  \
# 0   raw_signal   100       Ax_diff
# 1  autoencoder   200   w5_features
# 2          mlp  2800   w5_features
# 3      conv_nn  2200  all_features
# 4         lstm   200   w5_features
# 5          gru   300  all_features
# 6       bilstm   100  w15_features
# 7  transformer   301  w15_features
#
#                                                                                                                                               params  \
# 0                                                                                                                                                 {}
# 1                                                                                                              {'hidden_ae': [128, 56, 18, 56, 128]}
# 2                                                                                                                      {'hidden_mlp': [128, 64, 32]}
# 3                                                                                   {'filters': 1, 'kernel_size': 3, 'hidden': [64, 32], 'w_len': 5}
# 4                                                                                                                    {'time_steps': 5, 'units': 128}
# 5                                                                                                                     {'time_steps': 5, 'units': 64}
# 6                                                                                                                    {'time_steps': 5, 'units': 128}
# 7  {'head_size': 256, 'num_heads': 4, 'ff_dim': 4, 'num_transformer_blocks': 4, 'mlp_units': [128], 'mlp_dropout': 0.4, 'dropout': 0.25, 'w_len': 5}
#
#    params_idx    cost  anticipation  detected_faults  missed_faults  \
# 0           0  306.40          0.46               13              0
# 1           2 2666.80          0.90               13              0
# 2           3  142.20          0.66               13              0
# 3          11  114.60          0.80               13              0
# 4           1  381.40          0.28               12              1
# 5           0  290.80          0.68               13              0
# 6           1  272.40          0.48               13              0
# 7           3  316.80          0.47               13              0
#
#    false_alarms
# 0           582
# 1         13334
# 2           236
# 3           398
# 4            62
# 5           974
# 6           322
# 7           549
